# %%
 #!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Sep 1 07:50:44 2020

@author: Mahathir bishal
"""


import csv
import pandas as pd


# converts downloaded 2 column csv to 1 colmn csv
print("ready_corona_tweets_149.csv file is creating...")
dataframe=pd.read_csv("Test(1334).csv", header=None)
dataframe=dataframe[0]
dataframe.to_csv("Test(1334).csv", index=False, header=None)
print("ready_corona_tweets_149.csv file created")
# Out:
# ready_corona_tweets_149.csv file is creating...
# ready_corona_tweets_149.csv file created

# %%
 pip install nltk

# %%
 import nltk
 from nltk import word_tokenize, pos_tag, pos_tag_sents
 import pandas as pd
 df = pd.read_csv('Test(1334).csv', sep=',')
 df['Text']
 nltk.download('averaged_perceptron_tagger')
 nltk.download('punkt')
 texts = df['Text'].tolist()
 tagged_texts = pos_tag_sents(map(word_tokenize, texts))
 tagged_texts

 df['POS'] = tagged_texts
 df
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                    Text                                                POS
# 0     need trust russian vaccine lobbies including w...  [(need, NN), (trust, NN), (russian, JJ), (vacc...
# 1     witnessed aged care staff referring residents ...  [(witnessed, VBN), (aged, VBN), (care, NN), (s...
# 2     oh get mean like large gathering people puttin...  [(oh, UH), (get, VB), (mean, JJ), (like, IN), ...
# 3               hope get coronavirus cough trifling ass  [(hope, NN), (get, VB), (coronavirus, JJ), (co...
# 4     why bollywood celebrities gets constipation pi...  [(why, WRB), (bollywood, NN), (celebrities, NN...
# ...

# %%
texts = df['Text'].tolist()
tagged_texts = pos_tag_sents(map(word_tokenize, texts))
df['POS Tag'] =  tagged_texts

### Creation set
tagged_texts
tags = set()
for sentence in tagged_texts:
  for i in sentence:
    tags.add(i[1])
tags = list(tags) 


## Tag count
final_list = []
i=0
for sentence in df['POS Tag']:
  tag_count = {}
  for i in sentence:
    if i[1] not in tag_count:
      tag_count[i[1]] = 1 
    else:
      tag_count[i[1]] +=1
  final_list.append(tag_count)
df['Tag Count'] =  final_list

for n, i in enumerate(final_list):
  df = df.combine_first(pd.DataFrame(i, index=[n+0]))


#### Rearrange columns

cols = ['Text','POS Tag']
for i in tags:
  cols.append(i)

df  = df[cols]
print (df)
# Out:
#                                                    Text  ... RBR
# 0     need trust russian vaccine lobbies including w...  ... NaN
# 1     witnessed aged care staff referring residents ...  ... NaN
# 2     oh get mean like large gathering people puttin...  ... NaN
# 3               hope get coronavirus cough trifling ass  ... NaN
# 4     why bollywood celebrities gets constipation pi...  ... NaN
# ...                                                 ...  ...  ..
# 1329  well know fav lockdown housemates bbnaija bbna...  ... NaN
# 1330  ive downloaded new test protect app really qui...  ... NaN
# 1331  mumbai aug15 need positive blood group plasma ...  ... NaN
# 1332                             didnt said 6 died with  ... NaN
# 1333  dont miss live debate vaccine mandates thursda...  ... NaN
#
# [1334 rows x 34 columns]

# %%
df.to_csv('Test_poscount.csv')

# %%
# Filling null values 
# with 0 
df.fillna(value = 0,  
          inplace = True) 
  
# Show the DataFrame 
print(df)
# Out:
#                                                    Text  ...  RBR
# 0     need trust russian vaccine lobbies including w...  ...  0.0
# 1     witnessed aged care staff referring residents ...  ...  0.0
# 2     oh get mean like large gathering people puttin...  ...  0.0
# 3               hope get coronavirus cough trifling ass  ...  0.0
# 4     why bollywood celebrities gets constipation pi...  ...  0.0
# ...                                                 ...  ...  ...
# 1329  well know fav lockdown housemates bbnaija bbna...  ...  0.0
# 1330  ive downloaded new test protect app really qui...  ...  0.0
# 1331  mumbai aug15 need positive blood group plasma ...  ...  0.0
# 1332                             didnt said 6 died with  ...  0.0
# 1333  dont miss live debate vaccine mandates thursda...  ...  0.0
#
# [1334 rows x 34 columns]

# %%
df.to_csv('Test_poscount_final.csv')
